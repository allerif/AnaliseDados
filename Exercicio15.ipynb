# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Nestes exercícios, você deve decidir qual é o gráfico visto em aula que melhor visualiza uma base de dados. Após decidir, você deverá criar a visualização usando o conteúdo exposto durante a aula e adicionar um pequeno parágrafo sobre um insights que pode ser extraido do gráfico.

# %% [markdown]
# ## 1\. Preços `outliers` de diamante

# %%
import seaborn as sns

data = sns.load_dataset("diamonds")
data.head(n = 1)
# Out:
#    carat    cut color clarity  depth  table  price     x     y     z
# 0   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43

# %%
diamonds = data[['price']]
diamonds.describe()
# Out:
#               price
# count  53940.000000
# mean    3932.799722
# std     3989.439738
# min      326.000000
# 25%      950.000000
# 50%     2401.000000
# 75%     5324.250000
# max    18823.000000

# %%
with sns.axes_style('whitegrid'):
    grafico = sns.boxplot(x=data['price'])
    grafico.set(title='Distribuição de Preço', xlabel='Preço');

# %% [markdown]
# **Insight do gráfico 1**: O gráfico corrobora as informações estastísticas da tabela vista acima.

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Correlação entre o do preço do diamante com seu peso (`carat`) agrupados por sua transparêcia (`clarity`)

# %%
import seaborn as sns

data = sns.load_dataset("diamonds")
data.head(n = 1)
# Out:
#    carat    cut color clarity  depth  table  price     x     y     z
# 0   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43

# %%
diamonds = data[['price','carat', 'clarity']]
diamonds.clarity.unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
sns.lmplot(x = 'price', y = 'carat', hue = 'clarity', col = 'clarity', data = diamonds)

# %% [markdown]
# **Insight do gráfico 2**: Visualmente, todos possuem uma correlação positiva.

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Distribuição contínua aproximada do peso (`weight`) de carros

# %%
import seaborn as sns

data = sns.load_dataset("mpg")
data.head(n = 1)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu

# %%
cars = data[['weight']]

# %%
grafico = sns.histplot(data = cars, kde = True)
grafico.set(title='Distribuição contínua aproximada do peso', xlabel='Peso');

# %% [markdown]
# **Insight do gráfico 3**: Visualmente, é possível inferir que há maior quantidade de carros entre os pesos 2000 e 3000.

# %% [markdown]
# ---
